# %% [markdown]
# # Laptop Price Prediction - Exploratory Data Analysis (EDA)
#
# In this notebook, we will explore the dataset to understand relationships between features and the target variable (`Price_euros`).
# We will:
# 1. Explore numeric features (distributions, correlations)
# 2. Explore categorical features (company, type, etc.)
# 3. Visualize feature-target relationships

# %% [markdown]
# ### Step 0: Setup
# Import necessary libraries and load the cleaned dataset from `../data/processed/laptops_clean.csv`.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Make plots look nicer
sns.set(style="whitegrid")

# Load the cleaned dataset
data = pd.read_csv("../data/processed/laptops_clean.csv")

# Quick check
print("Shape:", data.shape)
data.head()
# Out:
# Shape: (1303, 30)
#   Company  Inches  Ram  Weight  Price_euros  SSD  HDD  Hybrid  Flash_Storage  \
# 0   Apple    13.3    8    1.37      1339.69  128    0       0              0
# 1   Apple    13.3    8    1.34       898.94    0    0       0            128
# 2      HP    15.6    8    1.86       575.00  256    0       0              0
# 3   Apple    15.4   16    1.83      2537.45  512    0       0              0
# 4   Apple    13.3    8    1.37      1803.60  256    0       0              0
#
#    Touchscreen  ...  Gpu_brand_Intel  Gpu_brand_Nvidia  OpSys_Chrome OS  \
# 0            0  ...             True             False            False
# 1            0  ...             True             False            False
# 2            0  ...             True             False            False
# 3            0  ...            False             False            False
# 4            0  ...             True             False            False
#
#    OpSys_Linux  OpSys_Mac OS X  OpSys_No OS  OpSys_Windows 10  \
# 0        False           False        False             False
# 1        False           False        False             False
# 2        False           False         True             False
# 3        False           False        False             False
# 4        False           False        False             False
#
#    OpSys_Windows 10 S  OpSys_Windows 7  OpSys_macOS
# 0               False            False         True
# 1               False            False         True
# 2               False            False        False
# 3               False            False         True
# 4               False            False         True
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Step 1: Basic Statistics
# Check the shape, summary statistics, and missing values.

# %%
print("Shape of dataset:", data.shape)
print("\nMissing values:\n", data.isnull().sum())
data.describe()
# Out:
# Shape of dataset: (1303, 30)
#
# Missing values:
#  Company                 0
# Inches                  0
# Ram                     0
# Weight                  0
# Price_euros             0
# SSD                     0
# HDD                     0
# Hybrid                  0
# Flash_Storage           0
# Touchscreen             0
# X_res                   0
# Y_res                   0
# TypeName_Gaming         0
# TypeName_Netbook        0
# TypeName_Notebook       0
# TypeName_Ultrabook      0
# TypeName_Workstation    0
# Cpu_brand_Intel         0
# Cpu_brand_Samsung       0
# Gpu_brand_ARM           0
# Gpu_brand_Intel         0
# Gpu_brand_Nvidia        0
# OpSys_Chrome OS         0
# OpSys_Linux             0
# OpSys_Mac OS X          0
# OpSys_No OS             0
# OpSys_Windows 10        0
# OpSys_Windows 10 S      0
# OpSys_Windows 7         0
# OpSys_macOS             0
# dtype: int64
#             Inches          Ram       Weight  Price_euros          SSD  \
# count  1303.000000  1303.000000  1303.000000  1303.000000  1303.000000
# mean     15.017191     8.382195     2.038734  1123.686992   184.027629
# std       1.426304     5.084665     0.665475   699.009043   188.268689
# min      10.100000     2.000000     0.690000   174.000000     0.000000
# 25%      14.000000     4.000000     1.500000   599.000000     0.000000
# 50%      15.600000     8.000000     2.040000   977.000000   256.000000
# 75%      15.600000     8.000000     2.300000  1487.880000   256.000000
# max      18.400000    64.000000     4.700000  6099.000000  1024.000000
#
#                HDD       Hybrid  Flash_Storage  Touchscreen        X_res  \
# count  1303.000000  1303.000000    1303.000000  1303.000000  1303.000000
# mean    422.477360     9.034536       4.555641     0.147352  1768.193400
# std     528.006298    94.738890      30.274090     0.354593   470.888913
# min       0.000000     0.000000       0.000000     0.000000     4.000000
# 25%       0.000000     0.000000       0.000000     0.000000  1366.000000
# 50%       0.000000     0.000000       0.000000     0.000000  1920.000000
# 75%    1024.000000     0.000000       0.000000     0.000000  1920.000000
# max    2048.000000  1024.000000     512.000000     1.000000  3200.000000
#
#              Y_res
# count  1303.000000
# mean   1070.830391
# std     284.519410
# min     768.000000
# 25%     900.000000
# 50%    1080.000000
# 75%    1080.000000
# max    2160.000000

# %% [markdown]
# ### Step 2: Distribution of Price
# Visualize the distribution of the target variable to see its spread.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.histplot(data['Price_euros'], bins=50, kde=True)
plt.title("Distribution of Laptop Prices")
plt.xlabel("Price (Euros)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Step 3: Correlation Heatmap
# Check correlations among numeric features and price.

# %%
plt.figure(figsize=(22,8))
sns.heatmap(data.corr(numeric_only=True), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
plt.savefig("../reports/figures/correlation_heatmap.png")

# %% [markdown]
# ### Step 4: Price vs Company
# Check how average laptop price varies by company.

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="Company", y="Price_euros", data=data)
plt.xticks(rotation=45)
plt.title("Laptop Price by Company")
plt.show()
plt.savefig("../reports/figures/price_by_company.png")

# %% [markdown]
# ### Step 5: Price vs Laptop Type
# Check how average price varies by type (e.g., Ultrabook, Gaming).

# %%
eda = pd.read_csv("../data/raw/laptop_price.csv", encoding="ISO-8859-1")
sns.boxplot(x="TypeName", y="Price_euros", data=eda)
plt.xticks(rotation=45)
plt.title("Laptop Price by Type")
plt.show()
plt.savefig("../reports/figures/price_by_type.png")

# %% [markdown]
# ### Step 6: Price vs RAM
# Check how price changes with RAM size.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x="Ram", y="Price_euros", data=data)
plt.title("Price vs RAM")
plt.show()
plt.savefig("../reports/figures/price_by_ram.png")

# %% [markdown]
# ### Step 7: Price vs Weight
# Check if lighter laptops tend to cost more.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x="Weight", y="Price_euros", data=data)
plt.title("Price vs Weight")
plt.show()
plt.savefig("../reports/figures/price_by_weight.png")

# %% [markdown]
# ### Step 8: Save EDA Figures (Optional)
# We can save plots for reports/presentation.

# %%
plt.figure(figsize=(8,5))
sns.histplot(data["Price_euros"], bins=50, kde=True)
plt.savefig("../reports/figures/price_distribution.png")
